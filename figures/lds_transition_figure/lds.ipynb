# %%
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import *
import numpy as np

# %%
np.arange(0.85, 1.3, 0.05)
# Out:
# array([0.85, 0.9 , 0.95, 1.  , 1.05, 1.1 , 1.15, 1.2 , 1.25])

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.tight_layout()

def load_img(factor=1.0, i=0):
    print(f"{i}")
    
    latent_img = plt.imread(f"factor{factor}_latent{i}_latents.png")
    ax[0].imshow(latent_img)
    ax[0].axis("off")
    
    sample_img = plt.imread(f"factor{factor}_latent{i}_samples.png")
    ax[1].imshow(sample_img)
    ax[1].axis("off")
    fig.canvas.draw()

interact(load_img, factor=[0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.05, 1.10, 1.15, 1.20, 1.25], i=list(range(10)))
# Out:
# interactive(children=(Dropdown(description='factor', index=5, options=(0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.05, …
# <function __main__.load_img(factor=1.0, i=0)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
